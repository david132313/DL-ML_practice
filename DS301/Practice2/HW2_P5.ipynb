# %% [markdown]
# # HW2Q5
# ## （1）

# %% [markdown]
# 256 GPUs = 256 / 8 = 32 servers
#
# 256 GPUs × 64 = 16384 images per iteration
#
# terations per epoch=
# 16384/
# 131072
# ​=8
#
# Epoch time=8×0.37=
# 2.96 seconds

# %% [markdown]
# ##（2）

# %% [markdown]
# Throughput=
# time per iteration
# /images per iteration
# = 16384
# ​/ 0.37
#  ≈
# 44281.08 images/sec
# ​
#
#
#
# ​

# %% [markdown]
# ## （3）

# %% [markdown]
# 1024 GPUs = 1024 / 8 = 128 servers
#
# Images per iteration: 1024 × 64 = 65536
#
# Iterations per epoch:
# 131072
# /
# 65536
# =
# 2
#
# Time per iteration (from table, 128 servers): 0.41 seconds
#
# Epoch time=2×0.41=
# 0.82 seconds

# %% [markdown]
# ## （4）

# %% [markdown]
# Images per iteration: 65536
#
# Time per iteration: 0.41 seconds
#
# Throughput=
# 65536
# ​/ 0.41
#  ≈
# 159844 images/sec

# %% [markdown]
# ## （5）

# %% [markdown]
# 1 GPU: 64 images/0.3 s = 213.33 images/sec
#
# Ideal speedup at 256 GPUs = 256
#
# Actual speedup = 44281.08 / 213.33 ≈ 207.59
#
# Scaling efficiency = 207.59 / 256 ≈ 0.811 = 81.1%
#
# False
