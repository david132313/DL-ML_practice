# %% [markdown]
# # HW2
# ## problem6

# %% [markdown]
# ### (1)

# %% [markdown]
# Batch 1: max(1.5, 3.0, 2.5) = 3.0
#
# Batch 2: max(0.9, 2.5, 1.5) = 2.5
#
# Batch 3: max(2.5, 1.7, 0.7) = 2.5
#
# Total (sync)=3.0+2.5+2.5=
# 8.0 ms

# %% [markdown]
# ## (2)

# %% [markdown]
# Update1:
#
#  L1: 1.5 (after 1.5 ms)
#
# L2: 3.0
#
# L3: 2.5
#
# Update2:
#
# L1’s next finish = 1.5 + 0.9 = 2.4 ms
#
# L2: still at 3.0 ms
#
# L3: still at 2.5 ms
#
# Update 3:
#
# Next for L1: 2.4 + 2.5 = 4.9 ms
#
# L2: 3.0 ms
#
# L3: 2.5 ms
#
# Third update: L3 at 2.5 ms
