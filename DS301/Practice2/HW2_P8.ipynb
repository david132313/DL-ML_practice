# %% [markdown]
# # HW2
# ## Problem 8
# | Gradient | Staleness |
# | -------- | --------- |
# | g\[L1,1] | 0         |
# | g\[L1,2] | 0         |
# | g\[L1,3] | 1         |
# | g\[L1,4] | 0         |
# | g\[L2,1] | 2         |
# | g\[L2,2] | 2         |
